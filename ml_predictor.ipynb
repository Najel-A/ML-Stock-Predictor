# %%
import pandas as pd 
import numpy as np


df = pd.read_csv('hourly_stock_data.csv')
df.head()
# Out:
#                       Ticker                NVDA              NVDA.1  \
# 0                      Price                Open                High
# 1                   Datetime                 NaN                 NaN
# 2  2025-03-03 14:30:00+00:00  123.50499725341797  123.69999694824219
# 3  2025-03-03 15:30:00+00:00  119.51499938964844  120.19999694824219
# 4  2025-03-03 16:30:00+00:00  119.23999786376953               119.5
#
#                NVDA.2              NVDA.3    NVDA.4                AAPL  \
# 0                 Low               Close    Volume                Open
# 1                 NaN                 NaN       NaN                 NaN
# 2  118.30000305175781  119.51000213623047  90292423   241.7220001220703
# 3  118.51000213623047  119.22000122070312  38941419               241.5
# 4              118.25  118.41000366210938  30591168  241.22999572753906
#
#                AAPL.1              AAPL.2              AAPL.3    AAPL.4
# ...
